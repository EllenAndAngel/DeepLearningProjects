# %%
import numpy as np
from datetime import datetime

# %%
a = np.random.randn(100) #random floats
b = np.random.randn(100)
T = 100000

# %%
b
# Out:
# array([ -2.77068323e-01,  -1.03683904e+00,  -1.05943416e+00,
#          1.98137907e-01,   2.34315964e+00,   2.87312831e-01,
#          7.92728682e-01,  -3.17152354e-01,  -1.04580661e-01,
#         -1.02522101e-01,  -1.55826513e-01,   1.76515780e-01,
#          4.31804877e-01,  -7.43423256e-01,  -1.47980663e-02,
#          3.37522699e-01,  -2.08724922e+00,   7.39073185e-01,
#          5.87968769e-01,   6.12167540e-01,   1.03481410e+00,
#         -1.09403951e+00,  -9.41878280e-01,   6.47307867e-01,
#          1.45969661e+00,   3.68584432e-01,  -8.30272009e-01,
#         -1.50476454e+00,  -5.06488079e-01,  -6.11542995e-01,
#          1.42370529e+00,  -3.78447999e-01,  -1.52669755e+00,
#          7.27305288e-01,  -1.13771411e+00,   1.02300052e+00,
#         -1.41720869e-02,   6.35320122e-01,   1.15939130e-01,
#          7.70529090e-01,  -1.17750953e+00,  -6.31618285e-01,
#          7.76619824e-01,  -1.28664971e+00,   7.66903119e-01,
# ...
